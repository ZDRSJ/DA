# %%
import pandas as pd

df = pd.read_csv('./table/csv_table/price_data_eda.csv')
df
# Out:
#         Unnamed: 0 adr_gu adr_dong    번지    본번  부번     도로명         단지명  \
# 0                0    덕양구      고양동   454   454   0  읍내로 25  고양동우방유쉘아파트
# 1                1    덕양구      고양동   454   454   0  읍내로 25  고양동우방유쉘아파트
# 2                2    덕양구      고양동   454   454   0  읍내로 25  고양동우방유쉘아파트
# 3                3    덕양구      고양동   454   454   0  읍내로 25  고양동우방유쉘아파트
# 4                4    덕양구      고양동   454   454   0  읍내로 25  고양동우방유쉘아파트
# ...            ...    ...      ...   ...   ...  ..     ...         ...
# 152829      152829   일산서구      탄현동  1583  1583   0   현중로 5      탄현마을효성
# 152830      152830   일산서구      탄현동  1583  1583   0   현중로 5      탄현마을효성
# 152831      152831   일산서구      탄현동  1583  1583   0   현중로 5      탄현마을효성
# 152832      152832   일산서구      탄현동  1583  1583   0   현중로 5      탄현마을효성
# 152833      152833   일산서구      탄현동  1583  1583   0   현중로 5      탄현마을효성
#
#         전용면적(㎡)  면적라벨  거래금액(만원)   m2당금액(만원)  건축년도  year  month
# 0        84.930     3   25000.0  294.360061  2007  2012      1
# 1        84.930     3   22500.0  264.924055  2007  2012      3
# 2        59.990     1   16700.0  278.379730  2007  2012      3
# 3        59.990     1   17400.0  290.048341  2007  2012      3
# 4        84.930     3   24000.0  282.585659  2007  2012      3
# ...         ...   ...       ...         ...   ...   ...    ...
# 152829   99.760     3   49750.0  498.696872  2000  2021      9
# 152830   99.760     3   49750.0  498.696872  2000  2021      9
# 152831   99.760     3   50800.0  509.222133  2000  2021     10
# 152832   99.760     3   45700.0  458.099439  2000  2021     10
# 152833  134.955     3   61500.0  455.707458  2000  2021     12
#
# [152834 rows x 15 columns]

# %%
len(df['단지명'].unique())
# Out:
# 511

# %%
df2 = pd.read_csv('./table/csv_table/crawling_data_eda.csv')
df2
# Out:
#      Unnamed: 0                지번주소 adr_dong     번지  전용면적(㎡)  총세대수  총동수  room  \
# 0             0   경기도 고양시 대화동 2579       대화동   2579    84.63   668    8     3
# 1             1   경기도 고양시 대화동 2580       대화동   2580    84.86   811   10     3
# 2             2   경기도 고양시 대화동 2573       대화동   2573    84.43   706    8     3
# 3             3   경기도 고양시 대화동 2570       대화동   2570    84.26  1255   14     3
# 4             4  경기도 고양시 일산동 576-4       일산동  576-4    82.65   496    4     3
# ..          ...                 ...      ...    ...      ...   ...  ...   ...
# 399         399    경기도 고양시 화정동 936       화정동    936   102.48  1320   19     4
# 400         400    경기도 고양시 화정동 936       화정동    936   132.23  1320   19     4
# 401         401    경기도 고양시 화정동 936       화정동    936   132.23  1320   19     4
# 402         402    경기도 고양시 화정동 936       화정동    936   132.23  1320   19     4
# 403         403    경기도 고양시 화정동 961       화정동    961    49.59  1350   11     2
#
#     bath  traffic_label  학교시설  편의시설
# 0      2            2.0     4     8
# 1      2            1.0     4     7
# 2      2            1.0     4     6
# 3      2            1.0     4     8
# 4      2            1.0     3     7
# ..   ...            ...   ...   ...
# 399    2            2.0     4     5
# 400    2            2.0     4     5
# 401    2            2.0     4     5
# 402    2            2.0     4     5
# 403    1            2.0     3     4
#
# [404 rows x 12 columns]

# %%
len(df2['지번주소'].unique())
# Out:
# 107
